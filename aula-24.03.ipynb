# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient ("mongodb://root:rootpass@localhost:27017")
print(client.server_info()['version'])
# Out:
# 8.2.6

# %%
db = client['loja']
colecao = db['vendas']

# %%
dados = [
    {
        "cliente": "Ana",
        "produto": "Mouse",
        "categoria": "Informática",
        "quantidade": 2,
        "preco_unitario": 50,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 1),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Bruno",
        "produto": "Teclado",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 120,
        "cidade": "Jacarezinho",
        "data": datetime(2026, 3, 2),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Carla",
        "produto": "Caderno",
        "categoria": "Papelaria",
        "quantidade": 5,
        "preco_unitario": 15,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 2),
        "forma_pagamento": "Dinheiro"
    },
    {
        "cliente": "Daniel",
        "produto": "Caneta",
        "categoria": "Papelaria",
        "quantidade": 10,
        "preco_unitario": 3,
        "cidade": "Salto Grande",
        "data": datetime(2026, 3, 3),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Elaine",
        "produto": "Monitor",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 900,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 3),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Fabio",
        "produto": "Mochila",
        "categoria": "Acessórios",
        "quantidade": 2,
        "preco_unitario": 80,
        "cidade": "Jacarezinho",
        "data": datetime(2026, 3, 4),
        "forma_pagamento": "Boleto"
    },
    {
        "cliente": "Gabriela",
        "produto": "Livro",
        "categoria": "Livros",
        "quantidade": 3,
        "preco_unitario": 40,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 4),
        "forma_pagamento": "Pix"
    },
    {
        "cliente": "Henrique",
        "produto": "Fone",
        "categoria": "Informática",
        "quantidade": 2,
        "preco_unitario": 150,
        "cidade": "Assis",
        "data": datetime(2026, 3, 5),
        "forma_pagamento": "Cartão"
    },
    {
        "cliente": "Isabela",
        "produto": "Agenda",
        "categoria": "Papelaria",
        "quantidade": 4,
        "preco_unitario": 20,
        "cidade": "Salto Grande",
        "data": datetime(2026, 3, 5),
        "forma_pagamento": "Dinheiro"
    },
    {
        "cliente": "João",
        "produto": "Webcam",
        "categoria": "Informática",
        "quantidade": 1,
        "preco_unitario": 250,
        "cidade": "Ourinhos",
        "data": datetime(2026, 3, 6),
        "forma_pagamento": "Pix"
    }
]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c31873780be47caf48f21a'), ObjectId('69c31873780be47caf48f21b'), ObjectId('69c31873780be47caf48f21c'), ObjectId('69c31873780be47caf48f21d'), ObjectId('69c31873780be47caf48f21e'), ObjectId('69c31873780be47caf48f21f'), ObjectId('69c31873780be47caf48f220'), ObjectId('69c31873780be47caf48f221'), ObjectId('69c31873780be47caf48f222'), ObjectId('69c31873780be47caf48f223')], acknowledged=True)

# %%
dado_exemplo = list(colecao.find({'cliente' : 'Bruno'}))
display (dado_exemplo)
# Out:
# [{'_id': ObjectId('69c31873780be47caf48f21b'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
dados_mongo = list(colecao.find ({
    'preco_unitario': {'$gte' : 100, '$lte' : 300}
}))

display(dados_mongo)
# Out:
# [{'_id': ObjectId('69c31873780be47caf48f21b'),
#   'cliente': 'Bruno',
#   'produto': 'Teclado',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 120,
#   'cidade': 'Jacarezinho',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c31873780be47caf48f221'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31873780be47caf48f223'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
dados_cidade = list(colecao.find({
    'cidade' : {'$in': ['Ourinhos', 'Assis']}
}))

display (dados_cidade)
# Out:
# [{'_id': ObjectId('69c31873780be47caf48f21a'),
#   'cliente': 'Ana',
#   'produto': 'Mouse',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 50,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31873780be47caf48f21c'),
#   'cliente': 'Carla',
#   'produto': 'Caderno',
#   'categoria': 'Papelaria',
#   'quantidade': 5,
#   'preco_unitario': 15,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c31873780be47caf48f21e'),
#   'cliente': 'Elaine',
#   'produto': 'Monitor',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31873780be47caf48f220'),
#   'cliente': 'Gabriela',
#   'produto': 'Livro',
#   'categoria': 'Livros',
#   'quantidade': 3,
#   'preco_unitario': 40,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c31873780be47caf48f221'),
#   'cliente': 'Henrique',
#   'produto': 'Fone',
#   'categoria': 'Informática',
#   'quantidade': 2,
#   'preco_unitario': 150,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c31873780be47caf48f223'),
#   'cliente': 'João',
#   'produto': 'Webcam',
#   'categoria': 'Informática',
#   'quantidade': 1,
#   'preco_unitario': 250,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'}]

# %%
df = pd.DataFrame(dados_cidade)
df
# Out:
#                         _id   cliente  produto    categoria  quantidade  \
# 0  69c31873780be47caf48f21a       Ana    Mouse  Informática           2
# 1  69c31873780be47caf48f21c     Carla  Caderno    Papelaria           5
# 2  69c31873780be47caf48f21e    Elaine  Monitor  Informática           1
# 3  69c31873780be47caf48f220  Gabriela    Livro       Livros           3
# 4  69c31873780be47caf48f221  Henrique     Fone  Informática           2
# 5  69c31873780be47caf48f223      João   Webcam  Informática           1
#
#    preco_unitario    cidade       data forma_pagamento
# 0              50  Ourinhos 2026-03-01          Cartão
# 1              15  Ourinhos 2026-03-02        Dinheiro
# 2             900  Ourinhos 2026-03-03          Cartão
# 3              40  Ourinhos 2026-03-04             Pix
# 4             150     Assis 2026-03-05          Cartão
# 5             250  Ourinhos 2026-03-06             Pix

# %%
df['valor_total'] = df['quantidade'] * df['preco_unitario']
df.head(3)
# Out:
#                         _id cliente  produto    categoria  quantidade  \
# 0  69c31873780be47caf48f21a     Ana    Mouse  Informática           2
# 1  69c31873780be47caf48f21c   Carla  Caderno    Papelaria           5
# 2  69c31873780be47caf48f21e  Elaine  Monitor  Informática           1
#
#    preco_unitario    cidade       data forma_pagamento  valor_total
# 0              50  Ourinhos 2026-03-01          Cartão          100
# 1              15  Ourinhos 2026-03-02        Dinheiro           75
# 2             900  Ourinhos 2026-03-03          Cartão          900

# %%
faturamento = df['valor_total'].sum()
print("Faturamento total: " , faturamento)
# Out:
# Faturamento total:  1745

# %%
faturamento_categoria = df.groupby('categoria')['valor_total'].sum().sort_values(ascending=False)
faturamento_categoria
# Out:
# categoria
# Informática    1550
# Livros          120
# Papelaria        75
# Name: valor_total, dtype: int64

# %%
faturamento_produto = df.groupby('produto')['valor_total'].sum().sort_values(ascending=False)
faturamento_produto
# Out:
# produto
# Monitor    900
# Fone       300
# Webcam     250
# Livro      120
# Mouse      100
# Caderno     75
# Name: valor_total, dtype: int64

# %%
vendas_por_cidade = df['cidade'].value_counts()
vendas_por_cidade
# Out:
# cidade
# Ourinhos    5
# Assis       1
# Name: count, dtype: int64

# %%
media_valor_vendas = df['valor_total'].mean()
print(f"Média do valor das vendas: {media_valor_vendas: .2f}")
# Out:
# Média do valor das vendas:  290.83

# %%
produto_top = df.groupby('produto')['valor_total'].sum().idxmax()
produto_top
# Out:
# 'Monitor'

# %%
cidade_top = df['cidade'].value_counts.idxmax()
cidade_top
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 cidade_top = df['cidade'].value_counts.idxmax()
#       2 cidade_top
#
# AttributeError: 'function' object has no attribute 'idxmax'
