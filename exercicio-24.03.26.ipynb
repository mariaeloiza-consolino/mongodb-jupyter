# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime

# %%
client = MongoClient ("mongodb://root:rootpass@localhost:27017")
print(client.server_info()['version'])
# Out:
# 8.2.6

# %%
db = client['clinica']
colecao = db['atendimentos']

# %% [markdown]
# 1. Inserir os 50 registros na coleção 'atendimentos'.

# %%
dados = [
{"tutor":"Ana","animal":"Cachorro","nome_pet":"Rex1","servico":"Consulta","valor":120,"cidade":"Assis","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Bruno","animal":"Gato","nome_pet":"Mimi2","servico":"Vacinação","valor":95,"cidade":"Assis","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Carlos","animal":"Cachorro","nome_pet":"Thor3","servico":"Banho","valor":60,"cidade":"Assis","data":datetime(2026,3,3),"forma_pagamento":"Dinheiro"},
{"tutor":"Daniela","animal":"Ave","nome_pet":"Piu4","servico":"Exame","valor":180,"cidade":"Assis","data":datetime(2026,3,4),"forma_pagamento":"Cartão"},
{"tutor":"Eduardo","animal":"Gato","nome_pet":"Luna5","servico":"Consulta","valor":130,"cidade":"Assis","data":datetime(2026,3,5),"forma_pagamento":"Pix"},
{"tutor":"Fernanda","animal":"Cachorro","nome_pet":"Bob6","servico":"Vacinação","valor":90,"cidade":"Assis","data":datetime(2026,3,6),"forma_pagamento":"Dinheiro"},
{"tutor":"Gabriel","animal":"Coelho","nome_pet":"Pompom7","servico":"Consulta","valor":110,"cidade":"Assis","data":datetime(2026,3,7),"forma_pagamento":"Pix"},
{"tutor":"Helena","animal":"Cachorro","nome_pet":"Mel8","servico":"Cirurgia","valor":820,"cidade":"Assis","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Igor","animal":"Gato","nome_pet":"Simba9","servico":"Banho","valor":55,"cidade":"Assis","data":datetime(2026,3,9),"forma_pagamento":"Cartão"},
{"tutor":"Juliana","animal":"Cachorro","nome_pet":"Nina10","servico":"Consulta","valor":125,"cidade":"Assis","data":datetime(2026,3,10),"forma_pagamento":"Pix"},
{"tutor":"Lucas","animal":"Ave","nome_pet":"Sky11","servico":"Exame","valor":200,"cidade":"Assis","data":datetime(2026,3,11),"forma_pagamento":"Cartão"},
{"tutor":"Mariana","animal":"Gato","nome_pet":"Lili12","servico":"Consulta","valor":135,"cidade":"Assis","data":datetime(2026,3,12),"forma_pagamento":"Pix"},
{"tutor":"Nicolas","animal":"Cachorro","nome_pet":"Bolt13","servico":"Vacinação","valor":100,"cidade":"Assis","data":datetime(2026,3,13),"forma_pagamento":"Dinheiro"},
{"tutor":"Patricia","animal":"Cachorro","nome_pet":"Max14","servico":"Consulta","valor":140,"cidade":"Ourinhos","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Rafael","animal":"Gato","nome_pet":"Mia15","servico":"Banho","valor":65,"cidade":"Ourinhos","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Sofia","animal":"Cachorro","nome_pet":"Luna16","servico":"Cirurgia","valor":900,"cidade":"Ourinhos","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Thiago","animal":"Ave","nome_pet":"Blue17","servico":"Exame","valor":170,"cidade":"Ourinhos","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Vanessa","animal":"Gato","nome_pet":"Nino18","servico":"Consulta","valor":125,"cidade":"Ourinhos","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"William","animal":"Cachorro","nome_pet":"Thor19","servico":"Vacinação","valor":95,"cidade":"Ourinhos","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Beatriz","animal":"Coelho","nome_pet":"Fluffy20","servico":"Consulta","valor":115,"cidade":"Ourinhos","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Caio","animal":"Cachorro","nome_pet":"Spike21","servico":"Banho","valor":70,"cidade":"Ourinhos","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Diego","animal":"Gato","nome_pet":"Tom22","servico":"Consulta","valor":135,"cidade":"Ourinhos","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Elisa","animal":"Cachorro","nome_pet":"Mel23","servico":"Exame","valor":210,"cidade":"Ourinhos","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Felipe","animal":"Ave","nome_pet":"Kiwi24","servico":"Consulta","valor":120,"cidade":"Ourinhos","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Gisele","animal":"Gato","nome_pet":"Nina25","servico":"Vacinação","valor":85,"cidade":"Ourinhos","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Hugo","animal":"Cachorro","nome_pet":"Rex26","servico":"Consulta","valor":150,"cidade":"Ourinhos","data":datetime(2026,3,13),"forma_pagamento":"Cartão"},
{"tutor":"Iris","animal":"Cachorro","nome_pet":"Bob27","servico":"Consulta","valor":110,"cidade":"Pompeia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Joao","animal":"Gato","nome_pet":"Luna28","servico":"Banho","valor":60,"cidade":"Pompeia","data":datetime(2026,3,2),"forma_pagamento":"Dinheiro"},
{"tutor":"Karen","animal":"Cachorro","nome_pet":"Thor29","servico":"Cirurgia","valor":780,"cidade":"Pompeia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Leo","animal":"Ave","nome_pet":"Sky30","servico":"Exame","valor":160,"cidade":"Pompeia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Marta","animal":"Gato","nome_pet":"Mimi31","servico":"Consulta","valor":120,"cidade":"Pompeia","data":datetime(2026,3,5),"forma_pagamento":"Cartão"},
{"tutor":"Nelson","animal":"Cachorro","nome_pet":"Max32","servico":"Vacinação","valor":90,"cidade":"Pompeia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Olga","animal":"Coelho","nome_pet":"Pompom33","servico":"Consulta","valor":105,"cidade":"Pompeia","data":datetime(2026,3,7),"forma_pagamento":"Dinheiro"},
{"tutor":"Paulo","animal":"Cachorro","nome_pet":"Bolt34","servico":"Banho","valor":75,"cidade":"Pompeia","data":datetime(2026,3,8),"forma_pagamento":"Cartão"},
{"tutor":"Quezia","animal":"Gato","nome_pet":"Simba35","servico":"Consulta","valor":130,"cidade":"Pompeia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Renato","animal":"Cachorro","nome_pet":"Nina36","servico":"Exame","valor":190,"cidade":"Pompeia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Sara","animal":"Ave","nome_pet":"Blue37","servico":"Consulta","valor":115,"cidade":"Pompeia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Tiago","animal":"Gato","nome_pet":"Lili38","servico":"Vacinação","valor":85,"cidade":"Pompeia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
{"tutor":"Ursula","animal":"Cachorro","nome_pet":"Rex39","servico":"Consulta","valor":145,"cidade":"Marilia","data":datetime(2026,3,1),"forma_pagamento":"Pix"},
{"tutor":"Vitor","animal":"Gato","nome_pet":"Mia40","servico":"Banho","valor":70,"cidade":"Marilia","data":datetime(2026,3,2),"forma_pagamento":"Cartão"},
{"tutor":"Wesley","animal":"Cachorro","nome_pet":"Thor41","servico":"Cirurgia","valor":870,"cidade":"Marilia","data":datetime(2026,3,3),"forma_pagamento":"Cartão"},
{"tutor":"Xuxa","animal":"Ave","nome_pet":"Piu42","servico":"Exame","valor":175,"cidade":"Marilia","data":datetime(2026,3,4),"forma_pagamento":"Pix"},
{"tutor":"Yara","animal":"Gato","nome_pet":"Luna43","servico":"Consulta","valor":135,"cidade":"Marilia","data":datetime(2026,3,5),"forma_pagamento":"Dinheiro"},
{"tutor":"Zeca","animal":"Cachorro","nome_pet":"Bob44","servico":"Vacinação","valor":100,"cidade":"Marilia","data":datetime(2026,3,6),"forma_pagamento":"Pix"},
{"tutor":"Aline","animal":"Coelho","nome_pet":"Fluffy45","servico":"Consulta","valor":120,"cidade":"Marilia","data":datetime(2026,3,7),"forma_pagamento":"Cartão"},
{"tutor":"Bruna","animal":"Cachorro","nome_pet":"Spike46","servico":"Banho","valor":80,"cidade":"Marilia","data":datetime(2026,3,8),"forma_pagamento":"Dinheiro"},
{"tutor":"Cesar","animal":"Gato","nome_pet":"Tom47","servico":"Consulta","valor":140,"cidade":"Marilia","data":datetime(2026,3,9),"forma_pagamento":"Pix"},
{"tutor":"Dora","animal":"Cachorro","nome_pet":"Mel48","servico":"Exame","valor":220,"cidade":"Marilia","data":datetime(2026,3,10),"forma_pagamento":"Cartão"},
{"tutor":"Enzo","animal":"Ave","nome_pet":"Kiwi49","servico":"Consulta","valor":130,"cidade":"Marilia","data":datetime(2026,3,11),"forma_pagamento":"Pix"},
{"tutor":"Fabio","animal":"Gato","nome_pet":"Nina50","servico":"Vacinação","valor":90,"cidade":"Marilia","data":datetime(2026,3,12),"forma_pagamento":"Dinheiro"},
]

# %%
colecao.insert_many(dados)
# Out:
# InsertManyResult([ObjectId('69c3c57791b5a3674618beda'), ObjectId('69c3c57791b5a3674618bedb'), ObjectId('69c3c57791b5a3674618bedc'), ObjectId('69c3c57791b5a3674618bedd'), ObjectId('69c3c57791b5a3674618bede'), ObjectId('69c3c57791b5a3674618bedf'), ObjectId('69c3c57791b5a3674618bee0'), ObjectId('69c3c57791b5a3674618bee1'), ObjectId('69c3c57791b5a3674618bee2'), ObjectId('69c3c57791b5a3674618bee3'), ObjectId('69c3c57791b5a3674618bee4'), ObjectId('69c3c57791b5a3674618bee5'), ObjectId('69c3c57791b5a3674618bee6'), ObjectId('69c3c57791b5a3674618bee7'), ObjectId('69c3c57791b5a3674618bee8'), ObjectId('69c3c57791b5a3674618bee9'), ObjectId('69c3c57791b5a3674618beea'), ObjectId('69c3c57791b5a3674618beeb'), ObjectId('69c3c57791b5a3674618beec'), ObjectId('69c3c57791b5a3674618beed'), ObjectId('69c3c57791b5a3674618beee'), ObjectId('69c3c57791b5a3674618beef'), ObjectId('69c3c57791b5a3674618bef0'), ObjectId('69c3c57791b5a3674618bef1'), ObjectId('69c3c57791b5a3674618bef2'), ObjectId('69c3c57791b5a3674618bef3'), ObjectId('69c3c57791b5a3674618bef4'), ObjectId('69c3c57791b5a3674618bef5'), ObjectId('69c3c57791b5a3674618bef6'), ObjectId('69c3c57791b5a3674618bef7'), ObjectId('69c3c57791b5a3674618bef8'), ObjectId('69c3c57791b5a3674618bef9'), ObjectId('69c3c57791b5a3674618befa'), ObjectId('69c3c57791b5a3674618befb'), ObjectId('69c3c57791b5a3674618befc'), ObjectId('69c3c57791b5a3674618befd'), ObjectId('69c3c57791b5a3674618befe'), ObjectId('69c3c57791b5a3674618beff'), ObjectId('69c3c57791b5a3674618bf00'), ObjectId('69c3c57791b5a3674618bf01'), ObjectId('69c3c57791b5a3674618bf02'), ObjectId('69c3c57791b5a3674618bf03'), ObjectId('69c3c57791b5a3674618bf04'), ObjectId('69c3c57791b5a3674618bf05'), ObjectId('69c3c57791b5a3674618bf06'), ObjectId('69c3c57791b5a3674618bf07'), ObjectId('69c3c57791b5a3674618bf08'), ObjectId('69c3c57791b5a3674618bf09'), ObjectId('69c3c57791b5a3674618bf0a'), ObjectId('69c3c57791b5a3674618bf0b')], acknowledged=True)

# %% [markdown]
# 2. Consultar atendimentos com valor entre 90 e 200 reais.

# %%
dados_mongo = list(colecao.find ({
    'valor': {'$gte' : 90, '$lte' : 200}
}))

display(dados_mongo)
# Out:
# [{'_id': ObjectId('69c332abf17882460bbf0c3a'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3b'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3d'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3e'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3f'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c40'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c43'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c44'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c45'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c46'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c47'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4a'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4b'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4c'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4d'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4f'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c51'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c53'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c54'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c57'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c58'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c59'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5a'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5c'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5d'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5e'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c60'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c63'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c64'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c65'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c66'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c68'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c6a'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c6b'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618beda'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bedb'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bedd'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bede'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bedf'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee0'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee3'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee4'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee5'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee6'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee7'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618beea'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618beeb'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618beec'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618beed'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618beef'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef1'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef3'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef4'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef7'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef8'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef9'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618befa'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618befc'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618befd'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618befe'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf00'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf03'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf04'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf05'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf06'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf08'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf0a'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf0b'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'}]

# %% [markdown]
# 3. Consultar atendimentos das cidades Assis, Ourinhos, Pompeia e Marília.

# %%
dados_cidade = list(colecao.find({
    'cidade' : {'$in': ['Ourinhos', 'Assis', 'Pompeia', 'Marilia']}
}))

display (dados_cidade)
# Out:
# [{'_id': ObjectId('69c332abf17882460bbf0c3a'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3b'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3c'),
#   'tutor': 'Carlos',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor3',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3d'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3e'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c3f'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c40'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c41'),
#   'tutor': 'Helena',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel8',
#   'servico': 'Cirurgia',
#   'valor': 820,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c42'),
#   'tutor': 'Igor',
#   'animal': 'Gato',
#   'nome_pet': 'Simba9',
#   'servico': 'Banho',
#   'valor': 55,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c43'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c44'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c45'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c46'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c47'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c48'),
#   'tutor': 'Rafael',
#   'animal': 'Gato',
#   'nome_pet': 'Mia15',
#   'servico': 'Banho',
#   'valor': 65,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c49'),
#   'tutor': 'Sofia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Luna16',
#   'servico': 'Cirurgia',
#   'valor': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4a'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4b'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4c'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4d'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4e'),
#   'tutor': 'Caio',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike21',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c4f'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c50'),
#   'tutor': 'Elisa',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel23',
#   'servico': 'Exame',
#   'valor': 210,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c51'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c52'),
#   'tutor': 'Gisele',
#   'animal': 'Gato',
#   'nome_pet': 'Nina25',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c53'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c54'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c55'),
#   'tutor': 'Joao',
#   'animal': 'Gato',
#   'nome_pet': 'Luna28',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c56'),
#   'tutor': 'Karen',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor29',
#   'servico': 'Cirurgia',
#   'valor': 780,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c57'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c58'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c59'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5a'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5b'),
#   'tutor': 'Paulo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt34',
#   'servico': 'Banho',
#   'valor': 75,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5c'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5d'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5e'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c5f'),
#   'tutor': 'Tiago',
#   'animal': 'Gato',
#   'nome_pet': 'Lili38',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c60'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c61'),
#   'tutor': 'Vitor',
#   'animal': 'Gato',
#   'nome_pet': 'Mia40',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c62'),
#   'tutor': 'Wesley',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor41',
#   'servico': 'Cirurgia',
#   'valor': 870,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c63'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c64'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c65'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c66'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c67'),
#   'tutor': 'Bruna',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike46',
#   'servico': 'Banho',
#   'valor': 80,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c332abf17882460bbf0c68'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c69'),
#   'tutor': 'Dora',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel48',
#   'servico': 'Exame',
#   'valor': 220,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c332abf17882460bbf0c6a'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c332abf17882460bbf0c6b'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618beda'),
#   'tutor': 'Ana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex1',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bedb'),
#   'tutor': 'Bruno',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi2',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bedc'),
#   'tutor': 'Carlos',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor3',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bedd'),
#   'tutor': 'Daniela',
#   'animal': 'Ave',
#   'nome_pet': 'Piu4',
#   'servico': 'Exame',
#   'valor': 180,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bede'),
#   'tutor': 'Eduardo',
#   'animal': 'Gato',
#   'nome_pet': 'Luna5',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bedf'),
#   'tutor': 'Fernanda',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob6',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee0'),
#   'tutor': 'Gabriel',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom7',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee1'),
#   'tutor': 'Helena',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel8',
#   'servico': 'Cirurgia',
#   'valor': 820,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee2'),
#   'tutor': 'Igor',
#   'animal': 'Gato',
#   'nome_pet': 'Simba9',
#   'servico': 'Banho',
#   'valor': 55,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee3'),
#   'tutor': 'Juliana',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina10',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee4'),
#   'tutor': 'Lucas',
#   'animal': 'Ave',
#   'nome_pet': 'Sky11',
#   'servico': 'Exame',
#   'valor': 200,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee5'),
#   'tutor': 'Mariana',
#   'animal': 'Gato',
#   'nome_pet': 'Lili12',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee6'),
#   'tutor': 'Nicolas',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt13',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Assis',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee7'),
#   'tutor': 'Patricia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max14',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee8'),
#   'tutor': 'Rafael',
#   'animal': 'Gato',
#   'nome_pet': 'Mia15',
#   'servico': 'Banho',
#   'valor': 65,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bee9'),
#   'tutor': 'Sofia',
#   'animal': 'Cachorro',
#   'nome_pet': 'Luna16',
#   'servico': 'Cirurgia',
#   'valor': 900,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618beea'),
#   'tutor': 'Thiago',
#   'animal': 'Ave',
#   'nome_pet': 'Blue17',
#   'servico': 'Exame',
#   'valor': 170,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618beeb'),
#   'tutor': 'Vanessa',
#   'animal': 'Gato',
#   'nome_pet': 'Nino18',
#   'servico': 'Consulta',
#   'valor': 125,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618beec'),
#   'tutor': 'William',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor19',
#   'servico': 'Vacinação',
#   'valor': 95,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618beed'),
#   'tutor': 'Beatriz',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy20',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618beee'),
#   'tutor': 'Caio',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike21',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618beef'),
#   'tutor': 'Diego',
#   'animal': 'Gato',
#   'nome_pet': 'Tom22',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef0'),
#   'tutor': 'Elisa',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel23',
#   'servico': 'Exame',
#   'valor': 210,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef1'),
#   'tutor': 'Felipe',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi24',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef2'),
#   'tutor': 'Gisele',
#   'animal': 'Gato',
#   'nome_pet': 'Nina25',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef3'),
#   'tutor': 'Hugo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex26',
#   'servico': 'Consulta',
#   'valor': 150,
#   'cidade': 'Ourinhos',
#   'data': datetime.datetime(2026, 3, 13, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef4'),
#   'tutor': 'Iris',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob27',
#   'servico': 'Consulta',
#   'valor': 110,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef5'),
#   'tutor': 'Joao',
#   'animal': 'Gato',
#   'nome_pet': 'Luna28',
#   'servico': 'Banho',
#   'valor': 60,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef6'),
#   'tutor': 'Karen',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor29',
#   'servico': 'Cirurgia',
#   'valor': 780,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef7'),
#   'tutor': 'Leo',
#   'animal': 'Ave',
#   'nome_pet': 'Sky30',
#   'servico': 'Exame',
#   'valor': 160,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef8'),
#   'tutor': 'Marta',
#   'animal': 'Gato',
#   'nome_pet': 'Mimi31',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bef9'),
#   'tutor': 'Nelson',
#   'animal': 'Cachorro',
#   'nome_pet': 'Max32',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618befa'),
#   'tutor': 'Olga',
#   'animal': 'Coelho',
#   'nome_pet': 'Pompom33',
#   'servico': 'Consulta',
#   'valor': 105,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618befb'),
#   'tutor': 'Paulo',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bolt34',
#   'servico': 'Banho',
#   'valor': 75,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618befc'),
#   'tutor': 'Quezia',
#   'animal': 'Gato',
#   'nome_pet': 'Simba35',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618befd'),
#   'tutor': 'Renato',
#   'animal': 'Cachorro',
#   'nome_pet': 'Nina36',
#   'servico': 'Exame',
#   'valor': 190,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618befe'),
#   'tutor': 'Sara',
#   'animal': 'Ave',
#   'nome_pet': 'Blue37',
#   'servico': 'Consulta',
#   'valor': 115,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618beff'),
#   'tutor': 'Tiago',
#   'animal': 'Gato',
#   'nome_pet': 'Lili38',
#   'servico': 'Vacinação',
#   'valor': 85,
#   'cidade': 'Pompeia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf00'),
#   'tutor': 'Ursula',
#   'animal': 'Cachorro',
#   'nome_pet': 'Rex39',
#   'servico': 'Consulta',
#   'valor': 145,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 1, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf01'),
#   'tutor': 'Vitor',
#   'animal': 'Gato',
#   'nome_pet': 'Mia40',
#   'servico': 'Banho',
#   'valor': 70,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 2, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf02'),
#   'tutor': 'Wesley',
#   'animal': 'Cachorro',
#   'nome_pet': 'Thor41',
#   'servico': 'Cirurgia',
#   'valor': 870,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 3, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf03'),
#   'tutor': 'Xuxa',
#   'animal': 'Ave',
#   'nome_pet': 'Piu42',
#   'servico': 'Exame',
#   'valor': 175,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 4, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf04'),
#   'tutor': 'Yara',
#   'animal': 'Gato',
#   'nome_pet': 'Luna43',
#   'servico': 'Consulta',
#   'valor': 135,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 5, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf05'),
#   'tutor': 'Zeca',
#   'animal': 'Cachorro',
#   'nome_pet': 'Bob44',
#   'servico': 'Vacinação',
#   'valor': 100,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 6, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf06'),
#   'tutor': 'Aline',
#   'animal': 'Coelho',
#   'nome_pet': 'Fluffy45',
#   'servico': 'Consulta',
#   'valor': 120,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 7, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf07'),
#   'tutor': 'Bruna',
#   'animal': 'Cachorro',
#   'nome_pet': 'Spike46',
#   'servico': 'Banho',
#   'valor': 80,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 8, 0, 0),
#   'forma_pagamento': 'Dinheiro'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf08'),
#   'tutor': 'Cesar',
#   'animal': 'Gato',
#   'nome_pet': 'Tom47',
#   'servico': 'Consulta',
#   'valor': 140,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 9, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf09'),
#   'tutor': 'Dora',
#   'animal': 'Cachorro',
#   'nome_pet': 'Mel48',
#   'servico': 'Exame',
#   'valor': 220,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 10, 0, 0),
#   'forma_pagamento': 'Cartão'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf0a'),
#   'tutor': 'Enzo',
#   'animal': 'Ave',
#   'nome_pet': 'Kiwi49',
#   'servico': 'Consulta',
#   'valor': 130,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 11, 0, 0),
#   'forma_pagamento': 'Pix'},
#  {'_id': ObjectId('69c3c57791b5a3674618bf0b'),
#   'tutor': 'Fabio',
#   'animal': 'Gato',
#   'nome_pet': 'Nina50',
#   'servico': 'Vacinação',
#   'valor': 90,
#   'cidade': 'Marilia',
#   'data': datetime.datetime(2026, 3, 12, 0, 0),
#   'forma_pagamento': 'Dinheiro'}]

# %% [markdown]
# 4. Converter os resultados para DataFrame.

# %%
df = pd.DataFrame(dados_cidade)
df
# Out:
#                          _id    tutor    animal nome_pet    servico  valor  \
# 0   69c332abf17882460bbf0c3a      Ana  Cachorro     Rex1   Consulta    120
# 1   69c332abf17882460bbf0c3b    Bruno      Gato    Mimi2  Vacinação     95
# 2   69c332abf17882460bbf0c3c   Carlos  Cachorro    Thor3      Banho     60
# 3   69c332abf17882460bbf0c3d  Daniela       Ave     Piu4      Exame    180
# 4   69c332abf17882460bbf0c3e  Eduardo      Gato    Luna5   Consulta    130
# ..                       ...      ...       ...      ...        ...    ...
# 95  69c3c57791b5a3674618bf07    Bruna  Cachorro  Spike46      Banho     80
# 96  69c3c57791b5a3674618bf08    Cesar      Gato    Tom47   Consulta    140
# 97  69c3c57791b5a3674618bf09     Dora  Cachorro    Mel48      Exame    220
# 98  69c3c57791b5a3674618bf0a     Enzo       Ave   Kiwi49   Consulta    130
# 99  69c3c57791b5a3674618bf0b    Fabio      Gato   Nina50  Vacinação     90
#
#      cidade       data forma_pagamento
# 0     Assis 2026-03-01             Pix
# 1     Assis 2026-03-02          Cartão
# 2     Assis 2026-03-03        Dinheiro
# 3     Assis 2026-03-04          Cartão
# 4     Assis 2026-03-05             Pix
# ..      ...        ...             ...
# 95  Marilia 2026-03-08        Dinheiro
# 96  Marilia 2026-03-09             Pix
# 97  Marilia 2026-03-10          Cartão
# 98  Marilia 2026-03-11             Pix
# 99  Marilia 2026-03-12        Dinheiro
#
# [100 rows x 9 columns]

# %% [markdown]
# 5. Verificar valores nulos.

# %%
df.isnull().sum()
# Out:
# _id                0
# tutor              0
# animal             0
# nome_pet           0
# servico            0
# valor              0
# cidade             0
# data               0
# forma_pagamento    0
# dtype: int64

# %% [markdown]
# 6. Calcular faturamento total.

# %%
faturamento = df['valor'].sum()
print("Faturamento total: " , faturamento)
# Out:
# Faturamento total:  17790

# %% [markdown]
# 7. Calcular faturamento por cidade.

# %%
faturamento_por_cidade = df.groupby('cidade')['valor'].sum().sort_values(ascending=False)
faturamento_por_cidade
# Out:
# cidade
# Ourinhos    4760
# Marilia     4550
# Assis       4440
# Pompeia     4040
# Name: valor, dtype: int64

# %% [markdown]
# 8. Calcular faturamento por serviço.

# %%
faturamento_por_servico = df.groupby('servico')['valor'].sum().sort_values(ascending=False)
faturamento_por_servico
# Out:
# servico
# Cirurgia     6740
# Consulta     5310
# Exame        3010
# Vacinação    1660
# Banho        1070
# Name: valor, dtype: int64

# %% [markdown]
# 9. Calcular ticket médio geral.

# %%
ticket_medio_geral = df['valor'].mean()
print(f"Média do valor das consultas: {ticket_medio_geral: .2f}")
# Out:
# Média do valor das consultas:  177.90

# %% [markdown]
# 10. Calcular ticket médio por cidade.

# %%
ticket_medio_por_cidade = df.groupby('cidade')['valor'].mean().round(2)
print(f"Média do valor das consultas por cidade: { ticket_medio_por_cidade}")
# Out:
# Média do valor das consultas por cidade: cidade
# Assis       170.77
# Marilia     189.58
# Ourinhos    183.08
# Pompeia     168.33
# Name: valor, dtype: float64

# %% [markdown]
# 11. Identificar o serviço mais lucrativo.

# %%
servico_mais_lucrativo = df.groupby('servico')['valor'].sum().idxmax()
servico_mais_lucrativo
# Out:
# 'Cirurgia'

# %% [markdown]
# 12. Identificar a cidade com maior faturamento.

# %%
cidade_maior_faturamento = df['cidade'].value_counts().idxmax()
cidade_maior_faturamento
# Out:
# 'Assis'

# %% [markdown]
# 13. Identificar os 3 maiores atendimentos.

# %%
top_3_atendimentos = df.nlargest(3, 'valor')[['servico', 'valor']]
top_3_atendimentos
# Out:
#      servico  valor
# 15  Cirurgia    900
# 65  Cirurgia    900
# 40  Cirurgia    870

# %% [markdown]
# RELATÓRIO

# %%
relatorio ={
    'data_geracao' : datetime.now(),
    'faturamento_total': float(faturamento),
    'faturamento_por_cidade' : faturamento_por_cidade.to_dict(),
    'faturamento_por_servico' : faturamento_por_servico.to_dict(),
    'ticket_medio_geral' : float(ticket_medio_geral),
    'ticket_medio_por_cidade' :ticket_medio_por_cidade.to_dict(),
    'servico_mais_lucrativo' : servico_mais_lucrativo,
    'cidade_maior_faturamento' :  cidade_maior_faturamento,
    "top_3_atendimentos": df.nlargest(3, 'valor').to_dict('records')
}

display(relatorio)
# Out:
# {'data_geracao': datetime.datetime(2026, 3, 25, 11, 26, 51, 674657),
#  'faturamento_total': 17790.0,
#  'faturamento_por_cidade': {'Ourinhos': 4760,
#   'Marilia': 4550,
#   'Assis': 4440,
#   'Pompeia': 4040},
#  'faturamento_por_servico': {'Cirurgia': 6740,
#   'Consulta': 5310,
#   'Exame': 3010,
#   'Vacinação': 1660,
#   'Banho': 1070},
#  'ticket_medio_geral': 177.9,
#  'ticket_medio_por_cidade': {'Assis': 170.77,
#   'Marilia': 189.58,
#   'Ourinhos': 183.08,
#   'Pompeia': 168.33},
#  'servico_mais_lucrativo': 'Cirurgia',
#  'cidade_maior_faturamento': 'Assis',
#  'top_3_atendimentos': [{'_id': ObjectId('69c332abf17882460bbf0c49'),
#    'tutor': 'Sofia',
#    'animal': 'Cachorro',
#    'nome_pet': 'Luna16',
#    'servico': 'Cirurgia',
#    'valor': 900,
#    'cidade': 'Ourinhos',
#    'data': Timestamp('2026-03-03 00:00:00'),
#    'forma_pagamento': 'Cartão'},
#   {'_id': ObjectId('69c3c57791b5a3674618bee9'),
#    'tutor': 'Sofia',
#    'animal': 'Cachorro',
#    'nome_pet': 'Luna16',
#    'servico': 'Cirurgia',
#    'valor': 900,
#    'cidade': 'Ourinhos',
#    'data': Timestamp('2026-03-03 00:00:00'),
#    'forma_pagamento': 'Cartão'},
#   {'_id': ObjectId('69c332abf17882460bbf0c62'),
#    'tutor': 'Wesley',
#    'animal': 'Cachorro',
#    'nome_pet': 'Thor41',
#    'servico': 'Cirurgia',
#    'valor': 870,
#    'cidade': 'Marilia',
#    'data': Timestamp('2026-03-03 00:00:00'),
#    'forma_pagamento': 'Cartão'}]}

# %%
colecao_relatorios = db['relatorios']
colecao_relatorios.insert_one(relatorio)
# Out:
# InsertOneResult(ObjectId('69c3c67e91b5a3674618bf0e'), acknowledged=True)

# %%
for r in colecao_relatorios.find():
    display(r)
# Out:
# {'_id': ObjectId('69c3c5ca91b5a3674618bf0d'),
#  'data_geracao': datetime.datetime(2026, 3, 25, 11, 23, 51, 958000),
#  'faturamento_total': 17790.0,
#  'faturamento_cidade': {'Ourinhos': 4760,
#   'Marilia': 4550,
#   'Assis': 4440,
#   'Pompeia': 4040},
#  'faturamento_servico': {'Cirurgia': 6740,
#   'Consulta': 5310,
#   'Exame': 3010,
#   'Vacinação': 1660,
#   'Banho': 1070},
#  'ticket_medio_geral': 177.9,
#  'ticket_medio_por_cidade': {'Assis': 170.77,
#   'Marilia': 189.58,
#   'Ourinhos': 183.08,
#   'Pompeia': 168.33},
#  'servico_mais_lucrativo': 'Cirurgia',
#  'cidade_maior_faturamento': 'Assis',
#  'top_3_atendimentos': [{'_id': ObjectId('69c332abf17882460bbf0c49'),
#    'tutor': 'Sofia',
#    'animal': 'Cachorro',
#    'nome_pet': 'Luna16',
#    'servico': 'Cirurgia',
#    'valor': 900,
#    'cidade': 'Ourinhos',
#    'data': datetime.datetime(2026, 3, 3, 0, 0),
#    'forma_pagamento': 'Cartão'},
#   {'_id': ObjectId('69c3c57791b5a3674618bee9'),
#    'tutor': 'Sofia',
#    'animal': 'Cachorro',
#    'nome_pet': 'Luna16',
#    'servico': 'Cirurgia',
#    'valor': 900,
#    'cidade': 'Ourinhos',
#    'data': datetime.datetime(2026, 3, 3, 0, 0),
#    'forma_pagamento': 'Cartão'},
#   {'_id': ObjectId('69c332abf17882460bbf0c62'),
#    'tutor': 'Wesley',
#    'animal': 'Cachorro',
#    'nome_pet': 'Thor41',
#    'servico': 'Cirurgia',
#    'valor': 870,
#    'cidade': 'Marilia',
#    'data': datetime.datetime(2026, 3, 3, 0, 0),
#    'forma_pagamento': 'Cartão'}]}
# {'_id': ObjectId('69c3c67e91b5a3674618bf0e'),
#  'data_geracao': datetime.datetime(2026, 3, 25, 11, 26, 51, 674000),
#  'faturamento_total': 17790.0,
#  'faturamento_por_cidade': {'Ourinhos': 4760,
#   'Marilia': 4550,
#   'Assis': 4440,
#   'Pompeia': 4040},
#  'faturamento_por_servico': {'Cirurgia': 6740,
#   'Consulta': 5310,
#   'Exame': 3010,
#   'Vacinação': 1660,
#   'Banho': 1070},
#  'ticket_medio_geral': 177.9,
#  'ticket_medio_por_cidade': {'Assis': 170.77,
#   'Marilia': 189.58,
#   'Ourinhos': 183.08,
#   'Pompeia': 168.33},
#  'servico_mais_lucrativo': 'Cirurgia',
#  'cidade_maior_faturamento': 'Assis',
#  'top_3_atendimentos': [{'_id': ObjectId('69c332abf17882460bbf0c49'),
#    'tutor': 'Sofia',
#    'animal': 'Cachorro',
#    'nome_pet': 'Luna16',
#    'servico': 'Cirurgia',
#    'valor': 900,
#    'cidade': 'Ourinhos',
#    'data': datetime.datetime(2026, 3, 3, 0, 0),
#    'forma_pagamento': 'Cartão'},
#   {'_id': ObjectId('69c3c57791b5a3674618bee9'),
#    'tutor': 'Sofia',
#    'animal': 'Cachorro',
#    'nome_pet': 'Luna16',
#    'servico': 'Cirurgia',
#    'valor': 900,
#    'cidade': 'Ourinhos',
#    'data': datetime.datetime(2026, 3, 3, 0, 0),
#    'forma_pagamento': 'Cartão'},
#   {'_id': ObjectId('69c332abf17882460bbf0c62'),
#    'tutor': 'Wesley',
#    'animal': 'Cachorro',
#    'nome_pet': 'Thor41',
#    'servico': 'Cirurgia',
#    'valor': 870,
#    'cidade': 'Marilia',
#    'data': datetime.datetime(2026, 3, 3, 0, 0),
#    'forma_pagamento': 'Cartão'}]}
